# %%
import requests
from bs4 import BeautifulSoup
import time
import re

# %%
import pandas as pd
start = 1
result_df = pd.DataFrame()

while True:
    try:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%99%88%ED%8A%B8&sort=2&photo=0&field=0&pd=3&ds=2019.01.01&de=2020.01.01&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20190101to20200101,a:all&start={}'.format(start)
        headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
          'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        news_title = [title['title'] for title in soup.find_all('a', attrs={'class':'news_tit'})] # 기사 제목
        news_url = [ url['href'] for url in soup.find_all('a', attrs={'class':'news_tit'}) ] # 기사 url
        
        dates = [ date.get_text() for date in soup.find_all('span', attrs={'class':'info'})] # 기사 작성일
        news_date = []
        for date in dates:
            if re.search(r'\d+.\d+.\d+.', date) != None: # 기사 작성일 정제
                news_date.append(date)
                #print(news_date)
        #종료조건 확인
        if date == '2020.01.01.':
            break
        start += 10
        df = pd.DataFrame({'기사작성일':news_date,'기사제목':news_title,'기사주소':news_url})
        result_df = pd.concat([result_df, df], ignore_index=True)
        
    except: # 오류발생시 몇 페이지까지 크롤링했는지 page를 확인하기 
        print(start)
        break
# Out:
# 171

# %%
result_df
# Out:
#            기사작성일                                               기사제목  \
# 0    2019.01.02.  "움직이는 모든 것은 예술이다"…요가 통해 건강과 아름다움 찾게 도와주는 '플라잉 ...
# 1    2019.01.03.                           집안 운동기구 하나면 헬스장 비용도 다이어트
# 2    2019.01.04.                             새해, 운동 할 마음이 들게 하는 3단계
# 3    2019.01.04.      [박지홍 교수의 통증 잡는 '홈트'] 모로 누워 위쪽 팔 '쭉' 옆구리 스트레칭을
# 4    2019.01.04.              '새해 다이어트 시작', 비만 전문의가 조언하는 다이어트 성공 지침
# ..           ...                                                ...
# 165  2019.03.08.           K2, 스포츠웨어와 일상복 경계 허물다...'FLY 트레이닝 세트' 출시
# 166  2019.03.09.                        K2, 애슬레저 룩 ‘FLY 트레이닝 세트’ 출시
# 167  2019.03.10.           월드 톱8 개러지 공개 '집보다 낫네~'.."최고의 차고지로 임명합니다"
# 168  2019.03.11.                                 [패션 신제품] 마모트K2유니클로
# 169  2019.03.11.        5060세대 유튜브 장시간 이용자 그룹 2위로 우뚝 -19년 3월 10일(일)
#
#                                                   기사주소
# 0    http://www.kyeonggi.com/news/articleView.html?...
# 1    http://www.kookje.co.kr/news2011/asp/newsbody....
# 2    http://ize.co.kr/articleView.html?no=201901032...
# 3    http://health.chosun.com/site/data/html_dir/20...
# 4    http://www.koreadaily.com/news/read.asp?art_id...
# ..                                                 ...
# 165  http://www.ezyeconomy.com/news/articleView.htm...
# 166  http://moneys.mt.co.kr/news/mwView.php?no=2019...
# 167  http://www.gpkorea.com/news/articleView.html?i...
# 168  http://www.kukinews.com/news/article.html?no=6...
# 169  https://radio.ytn.co.kr/program/?f=2&id=61130&...
#
# [170 rows x 3 columns]

# %%
result_title = result_df["기사제목"]

# %%
result_title.to_csv('title_2019.txt', sep = '\t', index = False)

# %% [markdown]
# ### 2021

# %%
import pandas as pd
start = 1
result_df = pd.DataFrame()

while True:
    try:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%99%88%ED%8A%B8&sort=2&photo=0&field=0&pd=3&ds=2020.01.01&de=2021.01.01&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200101to20210101,a:all&start={}'.format(start)
        headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
          'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'}
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        news_title = [title['title'] for title in soup.find_all('a', attrs={'class':'news_tit'})] # 기사 제목
        news_url = [ url['href'] for url in soup.find_all('a', attrs={'class':'news_tit'}) ] # 기사 url
        
        dates = [ date.get_text() for date in soup.find_all('span', attrs={'class':'info'})] # 기사 작성일
        news_date = []
        for date in dates:
            if re.search(r'\d+.\d+.\d+.', date) != None: # 기사 작성일 정제
                news_date.append(date)
                #print(news_date)
        #종료조건 확인
        if date == '2021.01.01.':
            break
        start += 10
        df = pd.DataFrame({'기사작성일':news_date,'기사제목':news_title,'기사주소':news_url})
        result_df= pd.concat([result_df, df], ignore_index=True)
        
    except: # 오류발생시 몇 페이지까지 크롤링했는지 page를 확인하기 
        print(start)
        break
# Out:
# 27691

# %%
result_title = result_df["기사제목"]

# %%
result_df
# Out:
#              기사작성일                                               기사제목  \
# 0      2020.01.01.                  [봉쥬르 2020] 올해 주목해야 할 '5G·AI·구독경제'
# 1      2020.01.01.                 [오늘의 책]금연·다이어트…새해에도 작심삼일? '습관의 완성'
# 2      2020.01.01.              주말의 홈트ㅣ한수진의 요가 한 수, '잠자고있는 복근 깨우는 요가'
# 3      2020.01.01.  `괴팍한5형제` 방법에 대해 묻자, 김종국은 운동 얘기라면 한 회로는 모자란데라며 ...
# 4      2020.01.02.        '괴팍한5형제' 김종국 "빨 팬티 입고 운동하면 돼"...서장훈 기겁 '폭소'
# ...            ...                                                ...
# 27685  2020.09.16.                 윤세아 '홈트 여신'의 완벽한 점프 스쿼트··대단한 운동 열정
# 27686  2020.09.16.        '집콕'할 때 남친과 스킨십하며 몸도 만들 수 있는 '커플 홈트' 동작 6가지
# 27687  2020.09.16.                               애플은 운동 패러다임을 바꾸려고 한다
# 27688  2020.09.16.      부산 남구, 주민자치회 강사 대상 '온라인강의를 위한 동영상 촬영·편집' 특강 外
# 27689  2020.09.17.                               [세상읽기] 마음의 방역은 하셨나요?
#
#                                                     기사주소
# 0      http://www.asiatoday.co.kr/view.php?key=201912...
# 1      http://www.newsis.com/view/?id=NISX20191231_00...
# 2      https://www.hankyung.com/life/article/20191231...
# 3      http://www.ksilbo.co.kr/news/articleView.html?...
# 4      http://siminilbo.co.kr/news/newsview.php?ncode...
# ...                                                  ...
# 27685  http://biz.heraldcorp.com/view.php?ud=20200916...
# 27686              https://www.insight.co.kr/news/304090
# 27687                    https://byline.network/?p=54607
# 27688  http://www.kookje.co.kr/news2011/asp/newsbody....
# 27689  http://www.joongdo.co.kr/web/view.php?key=2020...
#
# [27690 rows x 3 columns]

# %%
result_title.to_csv('title_2019.txt', sep = '\t', index = False)
