# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
def verify(img1_path,img2_path):
    img1= cv2.imread(img1_path)
    img2= cv2.imread(img2_path)
    
    plt.imshow(img1[:,:,::-1])
    plt.show()
    plt.imshow(img2[:,:,::-1])
    plt.show()
    output = DeepFace.verify(img1_path,img2_path)
    print(output)
    verification = output['verified']
    if verification:
        
        print('They are same')
    else:
        print('The are not same')
verify('증사.jpeg','5.jpeg')
# Out:
# {'verified': True, 'distance': 0.10025245456194487, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same

# %%
def verify(img1_path,img2_path,model_name):
    img1= cv2.imread(img1_path)
    img2= cv2.imread(img2_path)
    plt.imshow(img1[:,:,::-1])
    plt.show()
    plt.imshow(img2[:,:,::-1])
    plt.show()
    output=DeepFace.verify(img1_path,img2_path,model_name=model_name)
    print(output)
    verification = output['verified']
   
    if verification:
        print('They are same')
    else:
        print('The are not same')

# %%
from deepface import DeepFace
img = cv2.imread('bts_test.jpeg')
imgplot = plt.imshow(img)
obj = DeepFace.analyze(img_path = "bts_1.jpeg", actions = ['age', 'gender', 'race', 'emotion'])

print(obj["age"]," years old ",obj["dominant_race"]," ",obj["dominant_emotion"]," ", obj["gender"])
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.77it/s]
# 32  years old  asian   surprise   Man

# %%
import cv2
import numpy as np
import face_recognition

imgtest = face_recognition.load_image_file('정국1.jpeg')
imgtest = cv2.cvtColor(imgtest, cv2.COLOR_BGR2RGB)

imgbts = face_recognition.load_image_file('bts_1.jpeg')
imgbts = cv2.cvtColor(imgbts, cv2.COLOR_BGR2RGB)

faceLoc = face_recognition.face_locations(imgtest)[0]
encodeElon = face_recognition.face_encodings(imgtest)[0]
cv2.rectangle(imgbts, (faceLoc[3], faceLoc[0]), (faceLoc[1], faceLoc[2]), (255, 0, 255), 2)

cv2.imshow('정국', imgtest)
cv2.imshow('bts_1', imgtest)
cv2.waitKey(0)
# Out:
# 27
