# %%
! pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.17.3 in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (from opencv-contrib-python) (1.20.1)

# %%
import os
import numpy as np
import cv2
import pickle

# %%
#load cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_alt2.xml')
recognizer = cv2.face.LBPHFaceRecognizer_create()

recognizer.read("trainner.yml")

# 피클로 라벨이름 불러오기
labels = {"person_name": 1}
with open("labels.pickle", 'rb') as f:
    og_labels = pickle.load(f)
    # key value pairs
    labels = {v:k for k,v in og_labels.items()}

# %%
# from mtcnn.mtcnn import MTCNN
# from math import sqrt
# detector = MTCNN()

# video_capture = cv2.VideoCapture(0)


# while True:
#     # Grab a single frame of video
#     ret, frame = video_capture.read()
    
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     #Use MTCNN to detect faces
#     faces = detector.detect_faces(frame)
#     if faces != []:
#         for person in faces:
#             bounding_box = person['box']
#             #for 
            
# #             print("faces:" + str(faces))
# #             print("[0]: " + str(bounding_box[0]))
# #             print("[1]: " + str(bounding_box[1]))
# #             print("bounding box:" + str(bounding_box))
#             x = bounding_box[0]
#             y = bounding_box[1]
#             w = bounding_box[2]
#             h = bounding_box[3]
#             cv2.rectangle(frame, (x,y), (x+w, y+h), (0,155,255), 2)
#             #print(x,y,w,h)
#             #circle(frame, (x,y), 반지름, 색깔, thickness)
#             #conf = faces[0]['confidence']
#             #print(conf)
#             #implements recognizer 얼굴인식기 구현
#             roi_gray = gray[y:y+h, x:x+w]
#             id_, conf = recognizer.predict(roi_gray)
#             if conf >= 70 and conf <= 100:
#                 print("labels[id_]" + str(conf))
#                 print(id_)
#                 print(labels[id_])
#                 font = cv2.FONT_HERSHEY_SIMPLEX
#                 name = labels[id_]
#                 color = (255, 0, 0)
#                 stroke = 2
#                 cv2.putText(frame, name, (x,y), font, 1, color, stroke, cv2.LINE_AA)
#             else:
#                 print("none:" + str(conf))
#                 face_img = frame[y:y+h, x:x+w] # 인식된 얼굴 이미지 crop
#                 face_img = cv2.resize(face_img, dsize=(0, 0), fx=0.04, fy=0.04) # 축소
#                 face_img = cv2.resize(face_img, (w, h), interpolation=cv2.INTER_AREA) # 확대
#                 frame[y:y+h, x:x+w] = face_img # 인식된 얼굴 영역 모자이크 처리


#     # Display the resulting image
#     cv2.imshow('Video', frame)

#     # Hit 'q' on the keyboard to quit!
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Release handle to the webcam
# video_capture.release()
# cv2.destroyAllWindows()

# %%
! pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (from mtcnn) (2.7.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (from mtcnn) (4.5.4.58)
# Requirement already satisfied: numpy>=1.17.3 in /Users/dayoung/opt/anaconda3/lib/python3.8/site-packages (from opencv-python>=4.1.0->mtcnn) (1.20.1)

# %%
from mtcnn.mtcnn import MTCNN
from math import sqrt
detector = MTCNN()

video_capture = cv2.VideoCapture(0)


while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()
    #min_score = 999 #가장 낮은 점수로 예측된 사람의 점수

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #Use MTCNN to detect faces
    
    faces = detector.detect_faces(frame)
    if faces != []:
        for person in faces:
            bounding_box = person['box']
            #for 
            
#             print("faces:" + str(faces))
#             print("[0]: " + str(bounding_box[0]))
#             print("[1]: " + str(bounding_box[1]))
#             print("bounding box:" + str(bounding_box))
            x = bounding_box[0]
            y = bounding_box[1]
            w = bounding_box[2]
            h = bounding_box[3]
            cv2.rectangle(frame, (x,y), (x+w, y+h), (0,155,255), 2)
            #print(x,y,w,h)
            #circle(frame, (x,y), 반지름, 색깔, thickness)
            #conf = faces[0]['confidence']
            #print(conf)
            #implements recognizer 얼굴인식기 구현
            roi_gray = gray[y:y+h, x:x+w]
            id_, conf = recognizer.predict(roi_gray)
            print(id_, conf)
            
            #minscore = conf
            #min_score 신뢰도이고 0에 가까울수록 자신과 같다는 뜻이다.
#             if min_score < 500:
# 
#                 conf = int(100*(1-(min_score)/300))
            if conf > 100:
                conf = int(conf / 10) #100 넘어가면 10으로 나눔
            
            if conf >= 60:
                print(labels[id_] + str(conf))
                # print(id_)
                # print(labels[id_])
                font = cv2.FONT_HERSHEY_SIMPLEX
                name = labels[id_]
                color = (255, 0, 0)
                stroke = 2
                display_string = str(int(conf)) + name
                cv2.putText(frame, display_string, (x,y), font, 1, color, stroke, cv2.LINE_AA)
            else:
                print("none:" + str(conf))
                face_img = frame[y:y+h, x:x+w] # 인식된 얼굴 이미지 crop
                face_img = cv2.resize(face_img, dsize=(0, 0), fx=0.04, fy=0.04) # 축소
                face_img = cv2.resize(face_img, (w, h), interpolation=cv2.INTER_AREA) # 확대
                frame[y:y+h, x:x+w] = face_img # 인식된 얼굴 영역 모자이크 처리


    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
# Out:
# 0 125.5368802329902
# none:12
# 0 111.93242271588569
# none:11
# 0 111.5461131600619
# none:11
# 0 111.43996475768184
# none:11
# 0 112.77703441088244
# none:11
# 0 104.85209175354052
# none:10
# 0 94.39543232645254
# images94.39543232645254
# 0 112.50058712304616
# none:11
# 0 94.30780770761699
# images94.30780770761699
# 0 113.17331244348856
# none:11
# 0 110.53744238526916
# none:11
# 0 93.21447449114746
# images93.21447449114746
# 0 105.88299708717453
# none:10
# 0 95.83577341888213
# images95.83577341888213
# 0 102.27300570255854
# none:10
# 0 90.62207219391523
# images90.62207219391523
# 0 116.30498120119191
# none:11
# 0 89.9116361635406
# images89.9116361635406
# 0 106.06347024496037
# none:10
# 0 80.31837664825062
# images80.31837664825062
# 0 106.91434832698594
# none:10
# 0 81.51753297663
# images81.51753297663
# 0 111.31052102504552
# none:11
# 0 82.47154355453083
# images82.47154355453083
# 0 111.93002503411623
# none:11
# 0 79.57515383778741
# images79.57515383778741
# 0 101.96027523640936
# none:10
# 0 100.44857277450797
# none:10
# 0 78.81133440801705
# images78.81133440801705
# 0 75.59226952141358
# images75.59226952141358
# 0 102.78362055956482
# none:10
# 0 79.62048552130075
# images79.62048552130075
# 0 102.94452148777079
# none:10
# 0 73.97313348000262
# images73.97313348000262
# 0 103.59324168412132
# none:10
# 0 104.18111552053549
# none:10
# 0 76.23329788714815
# images76.23329788714815
# 0 103.66760890670967
# none:10
# 0 75.11697501802388
# images75.11697501802388
# 0 78.59492296709637
# images78.59492296709637
# 0 106.38629037236795
# none:10
# 0 80.0891494396634
# images80.0891494396634
# 0 75.26674136623039
# images75.26674136623039
# 0 74.08909849632867
# images74.08909849632867
# 0 80.37895143756752
# images80.37895143756752
# 0 74.62585054888517
# images74.62585054888517
# 0 86.6534892840424
# images86.6534892840424
# 0 93.24446205995957
# images93.24446205995957
# 0 93.99845812121701
# images93.99845812121701
# 0 95.16993812338232
# images95.16993812338232
# 0 86.58851298065984
# images86.58851298065984
# 0 94.87461608073588
# images94.87461608073588
# 0 92.19412321070558
# images92.19412321070558
# 0 91.72533630771514
# images91.72533630771514
# 0 90.1649915827628
# images90.1649915827628
# 0 90.23620801579486
# images90.23620801579486
# 0 92.11442238491837
# images92.11442238491837
# 0 92.00268348175702
# images92.00268348175702
# 0 89.77173273033029
# images89.77173273033029
# 0 85.08325489413731
# images85.08325489413731
# 0 86.16916296955763
# images86.16916296955763
# 0 84.73157254343067
# images84.73157254343067
# 0 88.0103208420015
# images88.0103208420015
# 0 88.1831202948555
# images88.1831202948555
# 0 89.00269631977712
# images89.00269631977712
# 0 88.16706964757715
# images88.16706964757715
# 0 88.94064578844072
# images88.94064578844072
# 0 83.76718169643665
# images83.76718169643665
# 0 84.50959288494393
# images84.50959288494393
# 0 89.808579960191
# images89.808579960191
# 0 87.83276440604703
# images87.83276440604703
# 0 94.34461290424098
# images94.34461290424098
# 0 90.15329232854123
# images90.15329232854123
# 0 90.14906472753412
# images90.14906472753412
# 0 94.3188451794297
# images94.3188451794297
# 0 87.33113193392441
# images87.33113193392441
# 0 211.61314142934145
# none:21
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-f5105a81f09a> in <module>
#      60                 face_img = frame[y:y+h, x:x+w] # 인식된 얼굴 이미지 crop
#      61                 face_img = cv2.resize(face_img, dsize=(0, 0), fx=0.04, fy=0.04) # 축소
# ---> 62                 face_img = cv2.resize(face_img, (w, h), interpolation=cv2.INTER_AREA) # 확대
#      63                 frame[y:y+h, x:x+w] = face_img # 인식된 얼굴 영역 모자이크 처리
#      64
#
# error: OpenCV(4.5.4) /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/matrix.cpp:466: error: (-215:Assertion failed) _step >= minstep in function 'Mat'

# %%
from mtcnn.mtcnn import MTCNN
from math import sqrt
detector = MTCNN()

p_net.get_weights()
