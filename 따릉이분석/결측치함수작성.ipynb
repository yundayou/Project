# %%
import pandas as pd

df = pd.read_csv('pollution_dataset(2017-2020).csv')
df
# Out:
#        Unnamed: 0        측정일시  측정소명  이산화질소농도(ppm)  ...     년   월  미세먼지구간  초미세먼지구간
# 0               0  2016-01-01   강동구         0.043  ...  2016   1       2        2
# 1               1  2016-01-01   강서구         0.048  ...  2016   1       2        2
# 2               2  2016-01-01   광진구         0.046  ...  2016   1       3        3
# 3               3  2016-01-01   마포구         0.042  ...  2016   1       2        2
# 4               4  2016-01-01   서초구         0.038  ...  2016   1       2        2
# ...           ...         ...   ...           ...  ...   ...  ..     ...      ...
# 14075       14075  2020-12-31   마포구         0.022  ...  2020  12       1        1
# 14076       14076  2020-12-31   서초구         0.023  ...  2020  12       1        1
# 14077       14077  2020-12-31   송파구         0.027  ...  2020  12       1        1
# 14078       14078  2020-12-31  영등포구         0.021  ...  2020  12       1        1
# ...

# %%
print(df['오존농도(ppm)'].min())
print(df['오존농도(ppm)'].max())
# Out:
# 0.0
# 0.099
