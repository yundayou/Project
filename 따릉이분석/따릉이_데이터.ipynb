# %%
import pandas as pd
df1 = pd.read_csv('bike_2017.csv', encoding = 'cp949')
df2 = pd.read_csv('bike_2017_2.csv', encoding = 'cp949')
df3 = pd.read_csv('bike_2017_3.csv', encoding = 'cp949')
#print(df1.describe(), df1.head(), df1.tail(), df1.info())
print(df1)
# Out:
#         Unnamed: 0  대여소번호    보관소(대여소)명   자치구  ...     운동량   탄소량  이동거리(M) 이동시간(분)
# 0                0    102   망원역 1번출구 앞   마포구  ...   37.32  0.34   1450.0     9.0
# 1                1    102   망원역 1번출구 앞   마포구  ...   99.63  0.71   3110.0    19.0
# 2                2    102   망원역 1번출구 앞   마포구  ...   92.84  0.72   3080.0    15.0
# 3                3    102   망원역 1번출구 앞   마포구  ...  109.06  1.06   4590.0    20.0
# 4                4    102   망원역 1번출구 앞   마포구  ...   22.14  0.20    860.0     6.0
# ...            ...    ...          ...   ...  ...     ...   ...      ...     ...
# 262846      262846    257  신길삼거리(우리은행)  영등포구  ...  934.73  8.74  37660.0   207.0
# 262847      262847    257  신길삼거리(우리은행)  영등포구  ...  240.88  2.07   8900.0   252.0
# 262848      262848    257  신길삼거리(우리은행)  영등포구  ...  191.90  1.58   6810.0    57.0
# 262849      262849    257  신길삼거리(우리은행)  영등포구  ...  852.61  7.75  33440.0   245.0
# 262850      262850    257       신길삼거리(   NaN  ...     NaN   NaN      NaN     NaN
#
# ...
